# %% [markdown]
# # Risk Analysis of Boeing 737
#
#
# **Author**: Siva Kumar Murugesan Paramasivam,
# **Used Language**: Python,
# **Used Packages**: numpy, matplotlib, seaborn & missingno
#
# This analysis does not follows the typical data analysis foot print, but I have used many of the core concepts of data analysis.
#
#
# > This report is the Python version my Final Thesis report. My Thesis report titled "Risk comparison on all continents for Boeing 737" is completely analysed using Microsoft Excel --> Pivot Tables & Power Query.
#
# The main aim of this project is to analyse and compare the Boeing 737 family aircraft across all the continents in terms of safety and dependability from 1969 to 2020. This comparison overlays the risk of Boeing 737 family aircraft in each year and gives a detailed perspective on the safety issue on each continent. The data were collected from the first recorded flight of the Boeing 737 family from 1969 to April 2020, with 51 years, a total of 491 accidents with 5700 fatalities were recorded.
#
# The motivation behind the measurement of risk value is to get the comparative risk estimation of Boeing 737 aircraft accidents and to improve safety measures to reduce the fatality rate. The geographical analysis shows the risk that each continent possesses and also denotes the improvement in the safety measures on each continent.

# %% [markdown]
# ### This analysis has been completely analysed using Python, including packages numpy, pandas, matplotlib,  seaborn & missingno.

# %%
# Imports

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import missingno as msno

# Initializing the matplot library
plt.style.use('ggplot')

# Initializing the seaborn library
sns.set_context('notebook')

# %% [markdown]
# The input data is available in the form of an Excel file and each sheet comprises of vital data.
#
# > The data has been manually collected and registered into the Excel file.
#
# 1. Source Sheet --> Boeing 737 aircrafts accidents entries --> collected from [Accidents database](https://aviation-safety.net/database/types/Boeing-737-series/index).
# 2. B737_orders_&_accidents Sheet --> Boeing 737 aircrafts order history & accidents entries --> collected from [Order & Accidents database](http://www.b737.org.uk/sales.htm).
# 3. B737_Prices --> Each Boeing 737 aircrafts cost entries --> collected from [Each Boeing 737 Price database](https://www.boeing.com/company/about-bca/).

# %%
source_sht = pd.read_excel('b737.xlsx', sheet_name='Source')

# %% [markdown]
# Here the source sheet is the important sheet, as it holds the accidents entry. The overview of the source sheet...

# %%
source_sht.head()
# Out:
#     Date  Year                       Operator  Aircraft Model            Type  \
# 0  25343  1969                        Avianca  Boeing 737-159  Boeing 737-100
# 1  25683  1970  VASP - Viação Aérea São Paulo  Boeing 737-2A1  Boeing 737-200
# 2  25702  1970  VASP - Viação Aérea São Paulo  Boeing 737-200  Boeing 737-200
# 3  25745  1970                        Avianca  Boeing 737-159  Boeing 737-100
# 4  25768  1970                United Airlines  Boeing 737-222  Boeing 737-200
#
#    Flight Cycles                  Fight Nature  First Flight  \
# 0            NaN  Domestic Scheduled Passenger       25135.0
# 1            NaN                       Unknown       25382.0
# 2            NaN                       Unknown           NaN
# 3            NaN  Domestic Scheduled Passenger       25135.0
# 4            NaN  Domestic Scheduled Passenger       24897.0
#
#    Total Airframe Hours      Time                Cause  \
# 0                   NaN       NaN             Sabotage
# ...

# %%
# For actual missing values, uncomment the next line:
#print(source_sht.isna().sum())

# Just to visualize the missing values
msno.matrix(source_sht, color=[0.8,0.2,0.5],)

# %% [markdown]
# ## Data cleaning
#
# As you can clearly see, there are lot of entries with NA. The parameters like 'Flight Cycles', 'Total Airframe Hours' & 'Time' are important, but many NA in this columns make it not very usefull! So, we need to perform data cleaning by droping NAs.
#
# Many features might have been played a vital role in a typical data analysis, but with the risk analysis, we only require the risk provoiding features.

# %%
# First dropping NAs
source_sht_sort = source_sht.dropna(axis=1)

# Dropping the unnecessary columns 

col_drop = ['Date', 'Aircraft Model']

source_sht_sort = source_sht_sort.drop(columns=col_drop)
source_sht_sort
# Out:
#      Year            Type                       Fight Nature  \
# 0    1969  Boeing 737-100       Domestic Scheduled Passenger
# 1    1970  Boeing 737-200                            Unknown
# 2    1970  Boeing 737-200                            Unknown
# 3    1970  Boeing 737-100       Domestic Scheduled Passenger
# 4    1970  Boeing 737-200       Domestic Scheduled Passenger
# ..    ...             ...                                ...
# 486  2019  Boeing 737-400  International Scheduled Passenger
# 487  2019  Boeing 737-800       Domestic Scheduled Passenger
# 488  2020  Boeing 737-800  International Scheduled Passenger
# 489  2020  Boeing 737-800       Domestic Scheduled Passenger
# 490  2020  Boeing 737-500       Domestic Scheduled Passenger
#
#                               Cause     Phase  Fatality Category  \
# 0                          Sabotage  En Route         0    Cat-1
# 1                          Sabotage   Unknown         0    Cat-1
# ...

# %% [markdown]
# The location is only usefull to categorize the accident locations in a continent. So, we have to shorten the location, with only the name of the country.

# %%
# Function to extract the country name.

def country_extracter(string):
    str_split = string.split(',')
    return str_split[-1]

source_sht_sort['Country'] = source_sht_sort['Location'].apply(country_extracter)

source_sht_sort.drop(columns='Location', inplace=True)

source_sht_sort['Country'] = source_sht_sort['Country'].str.strip()
source_sht_sort.insert(1,'Acc',1)
source_sht_sort
# Out:
#      Year  Acc            Type                       Fight Nature  \
# 0    1969    1  Boeing 737-100       Domestic Scheduled Passenger
# 1    1970    1  Boeing 737-200                            Unknown
# 2    1970    1  Boeing 737-200                            Unknown
# 3    1970    1  Boeing 737-100       Domestic Scheduled Passenger
# 4    1970    1  Boeing 737-200       Domestic Scheduled Passenger
# ..    ...  ...             ...                                ...
# 486  2019    1  Boeing 737-400  International Scheduled Passenger
# 487  2019    1  Boeing 737-800       Domestic Scheduled Passenger
# 488  2020    1  Boeing 737-800  International Scheduled Passenger
# 489  2020    1  Boeing 737-800       Domestic Scheduled Passenger
# 490  2020    1  Boeing 737-500       Domestic Scheduled Passenger
#
#                               Cause     Phase  Fatality Category  \
# 0                          Sabotage  En Route         0    Cat-1
# ...

# %% [markdown]
# Here we can see that 'Chennai' is stated as a Country, which infact a State in India. So, we can change the state to country.

# %%
source_sht_sort['Country'].replace({'Chennai': 'India'}, inplace= True)

# %% [markdown]
# Now, the data looks clean and in the correct order. So, we can start our analysing..
#
# Here is a short summary of this data with regards to the total number of accident in each continent.

# %%
fig, ax = plt.subplots(figsize=(10,6))
sns.countplot(x='Continent', data=source_sht, palette='CMRmap')
plt.title('Number of Accidents in each continent')
plt.ylabel('Number of Accidents')
plt.show()

# %% [markdown]
# Here is the same data represented with the Year index. It is represented as a Pivot table!!

# %%
year_fatality = source_sht_sort.pivot_table(index='Year', columns='Continent',\
                            values='Fatality', aggfunc= np.sum, \
                            margins='All', margins_name='Total', \
                            fill_value=0)
year_fatality.drop(index='Total', inplace=True)

# %%
fig, ax = plt.subplots(2,1,figsize=(18,8))

ax[0].plot(year_fatality.index, year_fatality['Total'])
ax[0].set_ylabel('Number of fatalities')
ax[0].set_xlim(xmin=1969, xmax=2020)

sns.countplot(x='Year', data=source_sht_sort, ax=ax[1])
ax[1].set_xticklabels(ax[1].get_xticklabels(), rotation=90)
plt.suptitle('Number of Fatalities with each accident')
plt.xlabel('Year')
plt.ylabel('Number of Accidents')
plt.show()

# %% [markdown]
# ## From here follows the risk analysis part..
#
# Each accident is already categorized by the Phase of an aircraft, when the accident occured and by the cause of accident. Inorder to start our analysis, we need to have the total kilometer (i.e... the entire Boeing 737 family aircarfts flown distance) and total number of flights (i.e... the entire Boeing 737 family aircarfts total flight)
#
# > As of April 2020, by approximation, the total Boeing 737 aircrafts flown Kilometre is 2.89 Billion Kilometers.
# > As of April 2020, by approximation, the total flights Boeing 737 aircrafts have flown is 191 Million Flights.
#
# The analysis part comprises of
# 1. Finding the probability of an accident
#     1. For a Kilometer
#         1. Phase of an accident
#         2. Cause of an accident
#     2. For a Flight
#         1. Phase of an accident
#         2. Cause of an accident
# 2. Risk measurement per flight
# 3. Risk measurement for a Year
# 4. Risk measurement in each Continent
#
# > This is sort of a dry part of this report, as everything will be tables and values. Insights are after the risk analysis part.

# %%
# Constants

DIST_IN_FLIGHT = 191948361
DIST_IN_KM = 289360606402

# %%
# To find the probability for each accident
# The total number of accidents are 491, so its divided by the constants!!

prob_per_flight = ((source_sht_sort.Fatality.count())/ DIST_IN_FLIGHT)
prob_per_km = ((source_sht_sort.Fatality.count())/ DIST_IN_KM)

# %%
# Phase
fig, ax = plt.subplots(figsize=(16,6))

sns.countplot(x='Phase', data=source_sht_sort, ax=ax, hue='Continent')
plt.title('Total number of Accident in each Phase', y=1.03)
plt.ylabel('Number of accident')
plt.show()

# %%
# Cause
fig, ax = plt.subplots(figsize=(18,6))

sns.countplot(x='Cause', data=source_sht_sort, ax=ax, hue='Continent')
plt.title('Total number of Accident in each Cause', y=1.03)
plt.ylabel('Number of accident')
ax.legend(loc='upper right')
plt.show()

# %% [markdown]
# In the probability of an accident for each phase/cause, the calculation resumbles as follows,
#
# "prob_(phase/cause)_cont_(km/flight)" is the total number of accident to a particular continent with respect to each phase/cause multiplied with the probability of accident(km/flight).
# "prob_per_(phase/cause)_(km/flight)" is the total number of accident to a particular phase/cause in respect to a continent, multiplied with the probability of accident(km/flight).
#
# __"prob_(phase/cause)_(km/flight)" represents the probability for each phase/cause of accident in each continent.__
#
# I prefer to use pivot table as its very convinent and also I have used the same in my original analysis.

# %%
# This function is to make the pivot table from the calculations:

def tab_generator(prob_tab, typ):
    
    "' Returns a Pivot table'"
    
    piv_tab = pd.DataFrame([prob_tab.index, prob_tab.values]).T
    piv_tab.columns = ['Location', 'Probability']
    piv_tab['Continent'] = piv_tab['Location'].apply(lambda x: x[0])
    piv_tab[typ] = piv_tab['Location'].apply(lambda x: x[1])
    piv_tab = piv_tab.drop(columns='Location')
    piv_tab.set_index('Continent')
    piv_tab = piv_tab.pivot_table(index="Continent", columns=typ, \
                         values='Probability',  \
                         aggfunc= np.sum)
    piv_tab.fillna(0, inplace=True)
    return piv_tab

# %% [markdown]
# ## For a Kilometer
#
# ### 1. Probability for each phase of accident

# %%
prob_phase_cont_km = source_sht_sort.groupby(['Continent','Phase'])['Phase'].count()
prob_per_phase_km = source_sht_sort.groupby('Phase')['Phase'].count()

prob_phase_km = (prob_phase_cont_km/prob_per_phase_km).apply(lambda x: x * prob_per_km)

# To pivot table:

prob_phase_km = tab_generator(prob_phase_km, 'Phase')

prob_phase_km
# Out:
# Phase              Approach      En Route       Landing       Parking  \
# Continent
# Africa         2.121056e-10  3.616226e-10  2.011723e-10  1.305265e-10
# Antarctica     0.000000e+00  0.000000e+00  2.623987e-11  6.526326e-11
# Asia           5.302640e-10  5.702511e-10  6.647433e-10  5.221060e-10
# Australia      0.000000e+00  0.000000e+00  8.746622e-12  0.000000e+00
# Europe         3.181584e-10  3.059884e-10  2.798919e-10  2.610530e-10
# North America  3.711848e-10  3.059884e-10  3.323716e-10  6.526326e-10
# South America  2.651320e-10  1.529942e-10  1.836791e-10  6.526326e-11
#
# Phase              Take Off        Taxing       Unknown
# Continent
# Africa         2.610530e-10  1.475517e-10  0.000000e+00
# Antarctica     0.000000e+00  0.000000e+00  0.000000e+00
# Asia           4.894744e-10  1.106638e-10  4.465381e-10
# Australia      0.000000e+00  1.106638e-10  0.000000e+00
# Europe         2.936847e-10  5.164310e-10  0.000000e+00
# ...

# %% [markdown]
# ### 2. Probability for each Cause of accident

# %%
prob_cause_cont_km = source_sht_sort.groupby(['Continent','Cause'])['Cause'].count()
prob_per_cause_km = source_sht_sort.groupby('Cause')['Cause'].count()

prob_cause_km = (prob_cause_cont_km/prob_per_cause_km).apply(lambda x: x * prob_per_km)

# To pivot table:

prob_cause_km = tab_generator(prob_cause_km, 'Cause')
prob_cause_km
# Out:
# Cause           Bird Strike  Electrical Faillure  Ground Vehicles collision  \
# Continent
# Africa         1.542586e-10         0.000000e+00               0.000000e+00
# Antarctica     0.000000e+00         0.000000e+00               5.473692e-11
# Asia           1.542586e-10         8.484223e-10               1.642108e-10
# Australia      0.000000e+00         0.000000e+00               1.094738e-10
# Europe         6.170344e-10         0.000000e+00               4.926323e-10
# North America  7.712930e-10         0.000000e+00               8.210539e-10
# South America  0.000000e+00         8.484223e-10               5.473692e-11
#
# Cause           Human Error  Landing Gear Structural Damage  \
# Continent
# Africa         1.339614e-10                    3.856465e-10
# Antarctica     4.465381e-11                    0.000000e+00
# Asia           4.018843e-10                    3.856465e-10
# Australia      4.465381e-11                    0.000000e+00
# ...

# %% [markdown]
# ## For a Flight
#
# ### 1. Probability for each phase of accident

# %%
prob_phase_cont_flight = source_sht_sort.groupby(['Continent','Phase'])['Phase'].count()
prob_per_phase_flight = source_sht_sort.groupby('Phase')['Phase'].count()

prob_phase_flight = (prob_phase_cont_flight/prob_per_phase_flight).apply(lambda x: x * prob_per_flight)

# To pivot table:

prob_phase_flight = tab_generator(prob_phase_flight, 'Phase')
prob_phase_flight
# Out:
# Phase              Approach      En Route       Landing       Parking  \
# Continent
# Africa         3.197475e-07  5.451432e-07  3.032656e-07  1.967677e-07
# Antarctica     0.000000e+00  0.000000e+00  3.955639e-08  9.838383e-08
# Asia           7.993686e-07  8.596489e-07  1.002095e-06  7.870707e-07
# Australia      0.000000e+00  0.000000e+00  1.318546e-08  0.000000e+00
# Europe         4.796212e-07  4.612750e-07  4.219348e-07  3.935353e-07
# North America  5.595580e-07  4.612750e-07  5.010476e-07  9.838383e-07
# South America  3.996843e-07  2.306375e-07  2.768947e-07  9.838383e-08
#
# Phase              Take Off        Taxing       Unknown
# Continent
# Africa         3.935353e-07  2.224330e-07  0.000000e+00
# Antarctica     0.000000e+00  0.000000e+00  0.000000e+00
# Asia           7.378787e-07  1.668248e-07  6.731525e-07
# Australia      0.000000e+00  1.668248e-07  0.000000e+00
# Europe         4.427272e-07  7.785155e-07  0.000000e+00
# ...

# %%
prob_cause_cont_flight = source_sht_sort.groupby(['Continent','Cause'])['Cause'].count()
prob_per_cause_flight = source_sht_sort.groupby('Cause')['Cause'].count()

prob_cause_flight = (prob_cause_cont_km/prob_per_cause_km).apply(lambda x: x * prob_per_flight)

# To pivot table:

prob_cause_flight = tab_generator(prob_cause_flight, 'Cause')
prob_cause_flight
# Out:
# Cause           Bird Strike  Electrical Faillure  Ground Vehicles collision  \
# Continent
# Africa         2.325436e-07             0.000000               0.000000e+00
# Antarctica     0.000000e+00             0.000000               8.251547e-08
# Asia           2.325436e-07             0.000001               2.475464e-07
# Australia      0.000000e+00             0.000000               1.650309e-07
# Europe         9.301744e-07             0.000000               7.426393e-07
# North America  1.162718e-06             0.000000               1.237732e-06
# South America  0.000000e+00             0.000001               8.251547e-08
#
# Cause           Human Error  Landing Gear Structural Damage  \
# Continent
# Africa         2.019458e-07                    5.813590e-07
# Antarctica     6.731525e-08                    0.000000e+00
# Asia           6.058373e-07                    5.813590e-07
# Australia      6.731525e-08                    0.000000e+00
# ...

# %% [markdown]
# ## 2. Risk measurement calculations..
#
# The accidents are usually categorized by the risk value (i.e... The total number fatality in an accident)
#
# These categorie of lossess are defined in the following order...
# > 1. **Cat-1** --> The accidents with no fatality.
# > 2. **Cat-2** --> The accidents with less than 25% fatality.
# > 3. **Cat-3** --> The accidents with less than 50% fatality.
# > 4. **Cat-4** --> The accidents with more than 50%, but less than 99% fatality.
# > 5. **Cat-5** --> The accidents with 100% fatality.
#
# In finding the risk value, we can use either the probability of an accident for km or flight. I have used the probability of an  accident for a flight. And it is usually calculated for the accident causes.

# %%
# Cat_mst is the Category measurement pivot table:

cat_mst = source_sht_sort.groupby(['Continent', 'Category'])['Category'].count()
cat_mst = tab_generator(cat_mst, "Category of Loss")
cat_mst
# Out:
# Category of Loss  Cat-1  Cat-2  Cat-3  Cat-4  Cat-5
# Continent
# Africa             51.0    4.0    1.0    4.0    7.0
# Antarctica          3.0    1.0    0.0    0.0    0.0
# Asia              110.0   16.0    2.0    9.0   21.0
# Australia           4.0    0.0    0.0    0.0    0.0
# Europe             71.0    5.0    2.0    2.0    7.0
# North America     103.0    8.0    0.0    5.0    4.0
# South America      37.0    6.0    1.0    2.0    5.0

# %% [markdown]
# #### Filtering out the outliers
#
# As the continent "__Antarctica__" and "__Australia__" have a total of 8 accidents with one "__Cat-2__" in antarctica. So, we can filter out both the continents as outliers. The "__Cat-1__" accidents can be omitted to better present the data graphically.
# So, these were the accidents that have resulted in atleast a 1% fatality.

# %%
cat_mst.drop(labels=['Antarctica', 'Australia'],inplace=True)

# %%
cat_mst.filter(items=['Cat-2','Cat-3','Cat-4', 'Cat-5']).plot(figsize=(14,6), kind='bar')
plt.title('Total number of accidents in each continents')
plt.ylabel('Total number of accidents')
plt.show()

# %% [markdown]
# Contructing a pivot table, by relating the Cause and Category.

# %%
# Total number of accidents in each category.
cat_risk = source_sht_sort.groupby(['Cause', 'Category'])['Category'].count()
cat_ptab = tab_generator(cat_risk, 'Category of Loss')
cat_ptab.index.name = 'Cause'
cat_ptab
# Out:
# Category of Loss                Cat-1  Cat-2  Cat-3  Cat-4  Cat-5
# Cause
# Bird Strike                      10.0    0.0    1.0    0.0    0.0
# Electrical Faillure               0.0    1.0    0.0    0.0    1.0
# Ground Vehicles collision        31.0    0.0    0.0    0.0    0.0
# Human Error                      26.0    2.0    1.0    3.0    6.0
# Landing Gear Structural Damage   22.0    0.0    0.0    0.0    0.0
# Manufacting Defects               2.0    0.0    0.0    0.0    2.0
# Mechanical Failure               56.0    3.0    2.0    4.0    8.0
# Other                            28.0    6.0    0.0    1.0    6.0
# Pilot Error                      48.0    7.0    1.0    7.0   16.0
# Sabotage                        104.0   15.0    0.0    3.0    4.0
# Weather                          52.0    6.0    1.0    4.0    1.0

# %% [markdown]
# ### Risk of an accident of each category of loss per undesirable event (Pj)
#
# This can be calculated by dividing the category loss in each cause to the total category loss. And the total number accidents in each cause, which is the 'prob_per_cause_flight'.
#
# > Pj = (Total number of accidents in that category for a cause )/(Total number of accidents for that cause))

# %%
pj = (cat_ptab.T / prob_per_cause_flight).T
pj
# Out:
# Category of Loss                   Cat-1     Cat-2     Cat-3     Cat-4  \
# Cause
# Bird Strike                     0.909091  0.000000  0.090909  0.000000
# Electrical Faillure             0.000000  0.500000  0.000000  0.000000
# Ground Vehicles collision       1.000000  0.000000  0.000000  0.000000
# Human Error                     0.684211  0.052632  0.026316  0.078947
# Landing Gear Structural Damage  1.000000  0.000000  0.000000  0.000000
# Manufacting Defects             0.500000  0.000000  0.000000  0.000000
# Mechanical Failure              0.767123  0.041096  0.027397  0.054795
# Other                           0.682927  0.146341  0.000000  0.024390
# Pilot Error                     0.607595  0.088608  0.012658  0.088608
# Sabotage                        0.825397  0.119048  0.000000  0.023810
# Weather                         0.812500  0.093750  0.015625  0.062500
#
# Category of Loss                   Cat-5
# Cause
# Bird Strike                     0.000000
# ...

# %%
drop_row = ['Bird Strike', 'Electrical Faillure', 'Ground Vehicles collision', 'Landing Gear Structural Damage', 'Manufacting Defects' ]

pj.drop(labels=drop_row).filter(items=(['Cat-2', 'Cat-3', 'Cat-4', 'Cat-5'])).\
            plot(kind='bar', figsize=(14,6))

plt.ylabel('Risk value')
plt.title('Risk value for each category')
plt.show()

# %% [markdown]
# ## 2. Risk Measurement per Flight in each Category [R(1/Flight)]
#
# > Typical formula to calculate the hazard measurement (zj).
#
# ![image.png](attachment:image.png)
#
# So, for this calculation, it is better to construct a table by adding the calculated values to the table.
#
# > R[1/Flight] = probability of an accident for each cause * zj

# %%
zj = pj.copy()
zj['Cat-1'] = pj['Cat-1'] + pj['Cat-2'] + pj['Cat-3'] + pj['Cat-4'] + pj['Cat-5']
zj['Cat-2'] = pj['Cat-2'] + pj['Cat-3'] + pj['Cat-4'] + pj['Cat-5']
zj['Cat-3'] = pj['Cat-3'] + pj['Cat-4'] + pj['Cat-5']
zj['Cat-4'] = pj['Cat-4'] + pj['Cat-5']

# %% [markdown]
# Now, the probability of an accident for a cause should be multiplied with the each cause. And then each category should be multiplied to each cause.

# %%
cause_prob = prob_per_cause_flight * prob_per_flight

# R[1/flight]

r_per_flight = (zj.T * cause_prob).T
r_per_flight
# Out:
# Category of Loss                   Cat-1     Cat-2     Cat-3     Cat-4  \
# Cause
# Bird Strike                     0.000028  0.000003  0.000003  0.000000
# Electrical Faillure             0.000005  0.000005  0.000003  0.000003
# Ground Vehicles collision       0.000079  0.000000  0.000000  0.000000
# Human Error                     0.000097  0.000031  0.000026  0.000023
# Landing Gear Structural Damage  0.000056  0.000000  0.000000  0.000000
# Manufacting Defects             0.000010  0.000005  0.000005  0.000005
# Mechanical Failure              0.000187  0.000043  0.000036  0.000031
# Other                           0.000105  0.000033  0.000018  0.000018
# Pilot Error                     0.000202  0.000079  0.000061  0.000059
# Sabotage                        0.000322  0.000056  0.000018  0.000018
# Weather                         0.000164  0.000031  0.000015  0.000013
#
# Category of Loss                   Cat-5
# Cause
# Bird Strike                     0.000000
# ...

# %%
r_per_flight.drop(labels=drop_row).plot(figsize=(14,6), kind='bar')
plt.ylabel('Risk value for an accident')
plt.title('Risk measurement [1/flight]')
plt.show()

# %% [markdown]
# ## 3. Risk measurement for a Year
#
# > R[1/Year] = Q_Accident × zj
#
# > Q_Accident = Total Number of Accidents in each Cause for a  period of Time (wj ) / Total Time Period
#
# Where, wj  values taken from 1969 to 2020
# Total period is from 1969 to 2020,which is 51 Years

# %%
q_acc = (prob_per_cause_flight / 51)
r_per_year =  (q_acc * zj.T).T
r_per_year
# Out:
# Category of Loss                   Cat-1     Cat-2     Cat-3     Cat-4  \
# Cause
# Bird Strike                     0.215686  0.019608  0.019608  0.000000
# Electrical Faillure             0.039216  0.039216  0.019608  0.019608
# Ground Vehicles collision       0.607843  0.000000  0.000000  0.000000
# Human Error                     0.745098  0.235294  0.196078  0.176471
# Landing Gear Structural Damage  0.431373  0.000000  0.000000  0.000000
# Manufacting Defects             0.078431  0.039216  0.039216  0.039216
# Mechanical Failure              1.431373  0.333333  0.274510  0.235294
# Other                           0.803922  0.254902  0.137255  0.137255
# Pilot Error                     1.549020  0.607843  0.470588  0.450980
# Sabotage                        2.470588  0.431373  0.137255  0.137255
# Weather                         1.254902  0.235294  0.117647  0.098039
#
# Category of Loss                   Cat-5
# Cause
# Bird Strike                     0.000000
# ...

# %%
r_per_year.filter(items=(['Cat-2', 'Cat-3', 'Cat-4', 'Cat-5'])).plot(figsize=(18,8))

# %%
fig, ax = plt.subplots(2,2, sharey=True, sharex=True, figsize=(20,10))

ax[0,0].plot(r_per_year.loc['Pilot Error'])
ax[0,0].set_title('Pilot Error')
ax[0,0].set_ylabel('Risk value for a year')
ax[0,1].plot(r_per_year.loc['Human Error'])
ax[0,1].set_title('Human Error')
ax[1,0].plot(r_per_year.loc['Other'])
ax[1,0].set_title('Other')
ax[1,0].set_ylabel('Risk value for a year')
ax[1,1].plot(r_per_year.loc['Mechanical Failure'])
ax[1,1].set_title('Mechanical Failure')

fig.suptitle('Risk measurement for a Year')
plt.show()

# %% [markdown]
# ## 4. Risk measurement in each Continent
#
# Now, we can calculate the risk in each continent, except for "__Australia__" and "__Antarctica__". It will be the same calculation, but only for the analysing continent.
#
# Okay!, First we can look the continents with larger number of accidents.

# %%
cat_mst.sort_values(by='Cat-1', ascending= False)
# Out:
# Category of Loss  Cat-1  Cat-2  Cat-3  Cat-4  Cat-5
# Continent
# Asia              110.0   16.0    2.0    9.0   21.0
# North America     103.0    8.0    0.0    5.0    4.0
# Europe             71.0    5.0    2.0    2.0    7.0
# Africa             51.0    4.0    1.0    4.0    7.0
# South America      37.0    6.0    1.0    2.0    5.0

# %%
source_piv = source_sht_sort.pivot_table(index='Continent', columns='Cause',\
                                        values = 'Acc',aggfunc='count',\
                                         fill_value=0)

source_piv.drop(labels=['Antarctica', 'Australia']).T.plot.bar(figsize=(16,6), stacked=True)
plt.ylabel('Number of accidents')
plt.title('Total number of accidents for each Cause', y=1.03)
# Out:
# Text(0.5, 1.03, 'Total number of accidents for each Cause')

# %% [markdown]
# ### Custom functions
#
# Inorder to perform risk analysis on each continent, this functions help to calculate the risk values and then plot them for each continent.
#
# A common function is described to form a data frame with the number of accidents in a specific continent to the remaining continents.
#     **man_errs** are the main cause of human made accidents.
#
# This custom function **risk_per_cont** takes continent name as an input argument and calculate the risk measurement value for a year.

# %%
def risk_per_cont(cont):
    
    "' Custom function to calculate and give insights on continent wise risk measurements'"
    
    cat_risk_cont = source_sht_sort[source_sht_sort.Continent == cont ].groupby(['Cause', 'Category'])['Category'].count()
    cat_cont_ptab = tab_generator(cat_risk_cont, 'Category of Loss')
    cat_cont_ptab.index.name = 'Cause'

    # Pj(accident)
    pj_cont = ((cat_cont_ptab.T) / prob_per_cause_flight).T

    # Zj, Hazardous measurement
    zj_cont = pj_cont.copy()
    
    # North america does not have a Cat-3 accident. So, we need to make sure it doesn't break our code.
    if cont == 'North America':
        zj_cont.insert(2, 'Cat-3', 0)
        zj_cont['Cat-1'] = pj_cont['Cat-1'] + pj_cont['Cat-2'] + pj_cont['Cat-4'] + pj_cont['Cat-5']
        zj_cont['Cat-2'] = pj_cont['Cat-2'] + pj_cont['Cat-4'] + pj_cont['Cat-5']
        zj_cont['Cat-4'] = pj_cont['Cat-4'] + pj_cont['Cat-5']
        
    else:
        zj_cont['Cat-1'] = pj_cont['Cat-1'] + pj_cont['Cat-2'] + pj_cont['Cat-3'] + pj_cont['Cat-4'] + pj_cont['Cat-5']
        zj_cont['Cat-2'] = pj_cont['Cat-2'] + pj_cont['Cat-3'] + pj_cont['Cat-4'] + pj_cont['Cat-5']
        zj_cont['Cat-3'] = pj_cont['Cat-3'] + pj_cont['Cat-4'] + pj_cont['Cat-5']
        zj_cont['Cat-4'] = pj_cont['Cat-4'] + pj_cont['Cat-5']
        

    # R[1/flight]
    r_per_flight_cont = (zj.T * cause_prob).T

    # R[1/year]
    r_per_year_cont = ((prob_per_cause_flight / 51) * zj_cont.T).T

    # Plot
    r_per_year_cont.drop(labels=drop_row).filter(items=(['Cat-2', 'Cat-3', 'Cat-4', 'Cat-5'])).plot.bar(figsize=(16,6))
    plt.title('Risk values for a year in {}'.format('cont'), y=1.03)
    plt.ylabel('Risk measurement value')
    plt.show()

# %%
man_errs = ['Ground Vehicles collision', 'Human Error', 'Manufacting Defects', 'Pilot Error', 'Sabotage']

# %%
# Custom function give detailed information in each continent.

# This function returns the top five Countries with most number of accidents

def top_countries(cont):
    top_cont = pd.DataFrame(source_sht[source_sht.Continent == cont].groupby('Country')['Country'].count())
    top_cont.nlargest(5,'Country').plot.bar(figsize=(10,6))
    plt.title('Countries accumulating most number of accidents in {}'.format(cont), y=1.03)
    plt.ylabel('Number of accidents')
    plt.show()

# %%
# Custom function, which returns a dataframe with number of accidents in a specific continent and the remaining continents.

def continent_desc(cont):
    
    source_cont = pd.DataFrame(source_piv[source_piv.index == cont].sum(), columns=[cont])
    wo_cont = pd.DataFrame(source_piv.drop(labels=[cont]).sum(),  columns=['Other Continents'])
    source_cont['Other Continents'] = wo_cont['Other Continents']
    
    # Graphical view:
    fig, ax = plt.subplots(1,2, figsize=(18,6), sharey=True)
    source_cont.drop(labels=man_errs).plot.bar(stacked=True, ax=ax[0])
    ax[0].set_title('Accidents without Human made Errors', y=1.03)
    ax[0].set_ylabel('Number of accidents')
    source_cont[source_cont.index.isin(man_errs)].plot.bar(stacked=True, ax=ax[1])
    ax[1].set_title('Accidents caused by Human made Errors', y=1.03)
    plt.show()

# %% [markdown]
# ### 1. Risk measurement in Asia
#
# Asia tops the list in each category. Majority of the accidents were man made errors. Now, we can examine the countries with most accidents in Asia.

# %%
top_countries('Asia')

# %%
continent_desc('Asia')

# %%
risk_per_cont('Asia')

# %% [markdown]
# The risk measurement in Asia shows that the total risk value for each category is higher than all other continents. Along with Europe, Asia has 2 category 3 accidents, with Asia having the risk value of 0.6275. In category 3, Weather plays a major role with risk value 0.0784. Category 4 has a total risk value of 0.5882.

# %% [markdown]
# ### 2. Risk measurement in North America.
#
# Now we can see the risk measurent in North America

# %%
top_countries('North America')

# %%
continent_desc('North America')

# %%
risk_per_cont('North America')

# %% [markdown]
# North America has the second-highest risk measurement value and the continent does not any accident in category 3. North America has 5 category 4 accidents, which accounted for 289 fatalities, resulting with a risk of 0.4340. North America has the fourth-lowest category 5 risk value with 0.1451. Pilot error accidents have been the most frequent accidents in category 5 in North America.

# %% [markdown]
# ### 3. Risk measurement in Europe
#
# Now we can see the risk measurent in Europe.

# %%
top_countries('Europe')

# %%
continent_desc('Europe')

# %%
risk_per_cont('Europe')

# %% [markdown]
# Europe as a continent has the third-highest risk measurement value, with 2 category 3 accidents have accumulated a severity of 0.4763. The category 4 has 2 accidents, which accounted for 117 fatalities with a risk of 0.4436. With 7 category 5 accidents resulting in a risk value of 0.3965, Europe has the second-highest risk value in category 5 across all continents.

# %% [markdown]
# ### 4. Risk measurement in Africa
#
# Now we can see the risk measurent in Africa.

# %%
top_countries('Africa')

# %%
continent_desc('Africa')

# %%
risk_per_cont('Africa')

# %% [markdown]
# The risk measurement in Africa gives the risk value for each cause in each category in Africa. In category 4, Africa as a continent has accounted for 4 accidents with 385 fatalities. Category 4 accidents in Africa is significantly higher with the total risk value of 0.2157. Sabotage and bad weather were the major causes of accidents. A total of 15.9% of category 5 accidents have occurred in Africa with a risk value of 0.1373. Africa as a continent does not have an accident in category 3 with a risk value of 0.2157.

# %% [markdown]
# ### 5. Risk measurement in South America
#
# Now we can see the risk measurent in South America.

# %%
top_countries('South America')

# %%
continent_desc('South America')

# %%
risk_per_cont('South America')

# %% [markdown]
# The risk measurement results in South America shows that the continent has lower risk values comparing to the other continents for Boeing 737 aircrafts. For category 3, South America has only one accident, which accounts for 40 fatalities. The category 4 has 2 accidents with 140 fatalities with risk value of 0.1150. With 5 category 5 accidents resulting in a risk value of 0.0780 for category 5.

# %% [markdown]
# Comparing the total severity from all the continents with each category shows that category 5 accidents have produced the higher number of fatalities across the continents. From each category, Asia as a continent has the highest risk value, as the continent has the highest total number of accident and fatalities. North America with the second-highest and Europe with the third-highest risk value across all the continents. Without considering Australia and Antarctica for its very low-risk value, South America has the least risk value.
#
# The category 2 and category 5 occurrences are the most common form of categorized accidents in the Boeing 737 family. In Asia and Europe, the category 5 accidents are more common than the defined categories except for the category 1 accidents. The probability of an occurrence for the category 3 accidents are the lowest as the category 3 accidents in Africa and North America have no registered accidents.

# %% [markdown]
# ## Conclusion
#
#
# This project intends to examine the risk of Boeing 737 aeroplane over all the continents from 1969 to 2020. A total of 491 accidents have occurred with 5700 fatalities. Human judgmental errors and airliners poor management and maintenance also have a big impact on these accidents.
#
# From the gathered data
#
#     1. Asia as a continent has the highest risk value with the risk value of 5.4511 per year and the probability of occurrence is 8.2E-07.
#
#     2. In Asia, India and Indonesia have recorded 36 and 35 accidents, which is 44.9% of the total accidents in Asia resulting in 1,104 fatalities.
#
#     3. Sabotage, Pilot Error and Mechanical Failure were the major causes, that have caused 45, 26 and 26 accidents in Asia.
#
#     4. The years between 2014-2020 have a total of 112 accidents, which is significantly higher than in the previous decades. But with 702 fatalities accumulating between 2014-2020, the fatality rate is lower.
#
#     5. The probability of an occurrence between 2014-2020 is 5.3%, in comparison, the accident rate between 1969-2013 is 11.87%.
#
#     6. The year 2005 had a total of 533 fatalities, which is the highest in 51 years for Boeing 737.
#
#     7. The probability of an occurrence for Category 2 is higher than the probability of an occurrence for category 5 by 72.8%.
#
#     8. In the total number of accidents, accidents that have led to at least one fatality were 112 accidents. The category 5 accidents have accounted for 39.2% in the 112 accidents.
#
# In conclusion, Asia as a continent has a higher risk value than other continents. The main reason behind most of the accidents were Human judgmental errors and airliners poor management and maintenance. In comparison, South America has the least risk value without the consideration of Australia and Antarctica. North America with 120 accidents has the second-highest number of accidents resulting in 614 fatalities.
#
# Even though the fatality rate is lower, the number of accidents occurred from 2014 is higher than years before, with the majority of the accidents were by the Human judgmental errors. Thus, with the constant improvement on aviation safety lowering the fatality rate, but the influence of human-made errors still accounts credible.
